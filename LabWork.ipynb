# %% [markdown]
# <a href="https://colab.research.google.com/github/chimi-pt/Compiler_C/blob/main/LabWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Compiler Construstion**
# **Lab Work**
# **100612 **

# %% [markdown]
# **LAB** 2

# %% [markdown]
# **Question 1**

# %% [markdown]
# Using any TWO examples, show the conversion of NFA to DFA
# [For assistance, I have attached two files on E-Learning to act as a guide. You are also
# free to use any other conversion methods that you prefer]
# For submission, you can draw the necessary diagrams by hand or using a computer tool,
# then attach a screenshot to your lab activity running file.

# %% [markdown]
# ![Screenshot from 2022-09-20 21-06-48.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2022-09-20 21-07-36.png](data:image/png;base64,...)

# %% [markdown]
# **Question 2**

# %% [markdown]
# Using the material on E-Learning, show how to use Flex and Bison when building a
# simple lexical analyzer.
